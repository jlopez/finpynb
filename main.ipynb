# %%
import dateparser
import requests
import time

from functools import cached_property

class Api:
    _UNITS = dict(m=60, h=3_600, D=86_400, M=2_592_000)
    _MAX_LIMIT = 10_000
    _CANDLES_URL = 'https://api.bitfinex.com/v2/candles/trade:{}:t{}/hist?limit={}&start={}&end={}&sort=-1'

    @staticmethod
    def split_pair(pair):
        if len(pair) == 6:
            return (pair[:3], pair[3:])
        return tuple(pair.split(':'))
    
    @staticmethod
    def make_pair(symbol1, symbol2):
        if len(symbol1) == 3 and len(symbol2) == 3:
            return symbol1 + symbol2
        return symbol1 + ':' + symbol2

    @classmethod
    def interval_to_ms(cls, interval):
        unit = interval[-1]
        value = int(interval[0:-1])
        return value * cls._UNITS[unit] * 1_000

    @cached_property
    def pairs(self):
        return tuple(requests.get('https://api-pub.bitfinex.com/v2/conf/pub:list:pair:exchange').json()[0])

    @cached_property
    def pair_map(self):
        data = {}
        for p in api.pairs:
            f, t = split_pair(p)
            d = data.setdefault(t, set()).add(f)

        return {k:tuple(sorted(v)) for k, v in data.items()}
    
    def ochl(self, *, symbol, interval=None, start=None, end=None):
        interval = interval or '1D'
        ts_start = dateparser.parse(start or '2013-01-01 UTC').timestamp() * 1_000
        ts_end = dateparser.parse(end or 'now').timestamp() * 1_000
        step = Api.interval_to_ms(interval)
        ts0 = ts_start
        while ts0 < ts_end:
            if ts0 > ts_start:
                time.sleep(1.1)
            limit = min((ts_end - ts0) // step, self._MAX_LIMIT)
            if not limit:
                break
            ts1 = ts0 + limit * step
            url = self._CANDLES_URL.format(interval, symbol, limit, ts0, ts1)
            yield from requests.get(url).json()
            ts0 = ts1
    
    def pd_ochl(self, *, symbol, interval=None, start=None, end=None):
        data = self.ochl(symbol=symbol, interval=interval, start=start, end=end)
        df = pd.DataFrame(data, columns='time open close high low volume'.split())
        df.drop_duplicates(inplace=True)
        df['time'] = pd.to_datetime(df['time'], unit='ms')
        df.set_index('time', inplace=True)
        df.sort_index(inplace=True)        
        return df

api = Api()

# %%
all_data = {s: api.pd_ochl(symbol=api.make_pair(s, 'USD')) for s in api.pair_map['USD']}

# %%
result = None
for sym, df in all_data.items():
    df = df['close']
    df.name = sym
    if result is None:
        result = df
    else:
        result = pd.merge(result, df, how='outer', left_index=True, right_index=True)

# %%
import json
with open('crypto.jsonl', 'w') as fp:
    for ts in result.index:
        record = dict(timestamp=str(ts))
        for symbol in all_data.keys():
            try:
                df = all_data[symbol].loc[ts]
                for label in df.index:
                    record.setdefault(label, {})[symbol] = df[label]
            except KeyError:
                pass
        json.dump(record, fp, separators=(',', ':'))
        fp.write('\n')

# %%
json.dump?
# Out:
# Signature:
# json.dump(
#     obj,
#     fp,
#     *,
#     skipkeys=False,
#     ensure_ascii=True,
#     check_circular=True,
#     allow_nan=True,
#     cls=None,
#     indent=None,
#     separators=None,
#     default=None,
#     sort_keys=False,
#     **kw,
# )
# Docstring:
# Serialize ``obj`` as a JSON formatted stream to ``fp`` (a
# ``.write()``-supporting file-like object).
#
# If ``skipkeys`` is true then ``dict`` keys that are not basic types
# (``str``, ``int``, ``float``, ``bool``, ``None``) will be skipped
# instead of raising a ``TypeError``.
#
# If ``ensure_ascii`` is false, then the strings written to ``fp`` can
# contain non-ASCII characters if they appear in strings contained in
# ``obj``. Otherwise, all such characters are escaped in JSON strings.
#
# If ``check_circular`` is false, then the circular reference check
# for container types will be skipped and a circular reference will
# result in an ``OverflowError`` (or worse).
#
# If ``allow_nan`` is false, then it will be a ``ValueError`` to
# serialize out of range ``float`` values (``nan``, ``inf``, ``-inf``)
# in strict compliance of the JSON specification, instead of using the
# JavaScript equivalents (``NaN``, ``Infinity``, ``-Infinity``).
#
# If ``indent`` is a non-negative integer, then JSON array elements and
# object members will be pretty-printed with that indent level. An indent
# level of 0 will only insert newlines. ``None`` is the most compact
# representation.
#
# If specified, ``separators`` should be an ``(item_separator, key_separator)``
# tuple.  The default is ``(', ', ': ')`` if *indent* is ``None`` and
# ``(',', ': ')`` otherwise.  To get the most compact JSON representation,
# you should specify ``(',', ':')`` to eliminate whitespace.
#
# ``default(obj)`` is a function that should return a serializable version
# of obj or raise TypeError. The default simply raises TypeError.
#
# If *sort_keys* is true (default: ``False``), then the output of
# dictionaries will be sorted by key.
#
# To use a custom ``JSONEncoder`` subclass (e.g. one that overrides the
# ``.default()`` method to serialize additional types), specify it with
# the ``cls`` kwarg; otherwise ``JSONEncoder`` is used.
# File:      /usr/local/Cellar/python@3.9/3.9.1_6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py
# Type:      function

# %%
print(str(pd.Timestamp.now()))
# Out:
# 2021-02-08 21:08:45.446359

# %%
api.pd_ochl(symbol='DOGUSD')
# Out:
#                open    close     high      low      volume
# time
# 2020-07-10   3879.0   3631.1   4950.0   3418.0  121.857898
# 2020-07-11   3508.0   3842.6   3938.4   3505.5   23.726461
# 2020-07-12   3771.1   3654.5   3840.3   3611.7    2.229347
# 2020-07-13   3604.8   3160.6   3610.7   3070.3   80.779781
# 2020-07-14   3155.0   3314.0   3360.6   3134.2   18.455876
# 2020-07-15   3280.7   3108.0   3339.2   3108.0   18.983336
# 2020-07-16   3137.5   3022.9   3137.5   2917.9  155.647223
# 2020-07-17   3025.4   3061.0   3108.5   2937.7   11.802551
# 2020-07-18   3060.2   3500.0   3744.7   3037.6   14.989777
# 2020-07-19   3500.0   3405.8   3845.2   3392.1   19.642741
# 2020-07-20   3405.8   3238.0   3437.0   3191.7   28.282078
# 2020-07-21   3300.0   3351.5   3351.5   3216.1    9.821409
# 2020-07-22   3275.0   3245.1   3337.3   3231.2   26.541103
# 2020-07-23   3292.4   3318.6   3324.5   3286.5    1.694849
# 2020-07-24   3311.5   3224.6   3337.3   3191.7   28.275807
# 2020-07-25   3214.7   3246.1   3278.4   3196.2    0.497342
# 2021-01-25   9063.4   8408.0   9909.0   8408.0    0.113197
# 2021-01-27   8126.0   7758.9   8512.3   7448.0    0.277438
# 2021-01-28   7449.0  33340.0  36000.0   7449.0   52.764079
# 2021-01-29  33339.0  46675.0  85372.0  28847.0  126.548090
# 2021-01-30  46714.0  28335.0  50800.0  22195.0   82.055348
# 2021-01-31  27900.0  36910.0  48010.0  26752.0   73.143148
# 2021-02-01  36541.0  34750.0  44900.0  33032.0   47.859699
# 2021-02-02  35101.0  31427.0  35200.0  29800.0   24.610336
# 2021-02-03  31558.0  37250.0  40464.0  31000.0   19.150209
# 2021-02-04  36910.0  52905.0  65000.0  35612.0  105.459416
# 2021-02-05  52905.0  46884.0  54000.0  43239.0   29.582130
# 2021-02-06  46700.0  57400.0  58624.0  44202.0   27.568594
# 2021-02-07  57990.0  78918.0  88000.0  53288.0   61.224897
# 2021-02-08  77777.0  79688.0  86396.0  62800.0   46.754937

# %%
all_data
# Out:
# {'AAVE': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ADA': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ALG': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'AMP': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ANT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'AST': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ATO': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'AVAX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'AVT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'B21X': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BAL': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BAND': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BAT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BCHABC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BCHN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BFT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BNT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BOX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BSV': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BTC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BTG': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BTSE': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'BTT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'CHZ': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'CLO': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'CND': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'COMP': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'CTX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DAI': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DAPP': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DAT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DGB': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DGX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DOG': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DOT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DRN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DSH': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DTA': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DTX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'DUSK': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'EDO': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'EGLD': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ENJ': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'EOS': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'EOSDT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ESS': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ETC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ETH': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ETH2X': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ETP': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'EUS': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'EUT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'EXRD': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'FET': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'FIL': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'FTT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'FUN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'GEN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'GNO': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'GNT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'GOT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'GTX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'HEZ': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'HOT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'IOS': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'IOT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'IQX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'JST': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'KAN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'KNC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'KSM': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'LEO': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'LINK': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'LRC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'LTC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'LYM': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'MAN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'MGO': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'MKR': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'MLN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'MNA': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'MTN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'NCA': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'NEC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'NEO': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'NUT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ODE': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'OKB': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'OMG': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'OMN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ONL': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ORS': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'PAS': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'PAX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'PLU': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'PNK': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'POA': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'QSH': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'QTM': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'RBT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'RCN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'REP': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'REQ': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'RIF': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'RINGX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'RRB': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'RRT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'SAN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'SNG': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'SNT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'SNX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'STJ': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'SUN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'SUSHI': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'SWM': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'TKN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'TRI': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'TRX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'TSD': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'UDC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'UNI': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'UOP': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'UOS': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'USK': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'UST': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'UTK': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'VEE': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'VET': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'VSY': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'WAX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'WBT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'WPR': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'WTC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XAUT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XCH': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XDC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XLM': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XMR': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XRA': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XRP': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XSN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XTZ': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'XVG': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'YFI': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'YGG': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'YYW': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ZBT': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ZCN': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ZEC': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ZIL': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: [],
#  'ZRX': Empty DataFrame
#  Columns: [open, close, high, low, volume]
#  Index: []}
